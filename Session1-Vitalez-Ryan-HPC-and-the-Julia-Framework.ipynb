# %%
include("Mandelbrot.jl")
# Out:
# Mandelbrot (generic function with 1 method)

# %%
?Mandelbrot
# Out:
# search: Mandelbrot
#   No documentation found.
#
#   Mandelbrot is a Function.
#
#   # 1 method for generic function "Mandelbrot":
#   [1] Mandelbrot(c) in Main at /Users/ryanvitalez/Mandelbrot.jl:1

# %%
include("PlotMandelbrot.jl")
# Out:
# plotMandelbrot (generic function with 2 methods)

# %%
?plotMandelbrot
# Out:
# search: plotMandelbrot
#   No documentation found.
#
#   plotMandelbrot is a Function.
#
#   # 2 methods for generic function "plotMandelbrot":
#   [1] plotMandelbrot(vrange::Tuple{Float64, Float64}; n) in Main at /Users/ryanvitalez/PlotMandelbrot.jl:15
#   [2] plotMandelbrot(xrange::Tuple{Float64, Float64}, yrange::Tuple{Float64, Float64}; n) in Main at /Users/ryanvitalez/PlotMandelbrot.jl:1

# %%
using Plots

# %%
plotMandelbrot((-1.0, 1.0); n=10_000)

# %%
plotMandelbrot( (-0.55, -0.5); n=10_000)

# %%
x = plotMandelbrot
# Out:
# plotMandelbrot (generic function with 2 methods)

# %%
@time x
# Out:
#   0.000001 seconds
# plotMandelbrot (generic function with 2 methods)
