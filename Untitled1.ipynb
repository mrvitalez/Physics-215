# %%
function generate( r, N )
    xval = rand();
    x = xval;
    for _ in 2:N
        xval = r * xval * (1 .- xval)
        x = vcat(x, xval)
    end
    return x;
end

generate(r) = generate( r, 200 )
# Out:
# generate (generic function with 2 methods)

# %%
x = generate(3.75)
# Out:
# 200-element Vector{Float64}:
#  0.7003364534374998
#  0.7869948953403167
#  0.6286272376822524
#  0.875456376473375
#  0.40887191012056223
#  0.9063587671309692
#  0.31827207140924535
#  0.8136560998879261
#  0.5685744412616075
#  0.9198657975212189
#  0.2764226702695156
#  0.7500494161146984
#  0.7030323356276189
#  ⋮
#  0.9338766681012006
#  0.23156638829025222
#  0.6672877353917264
#  0.832555550953154
#  0.5227755207384156
#  0.9355547837066025
#  0.22609511396360515
#  0.6561604252702108
#  0.846052205922851
#  0.4884295154097327
#  0.9369979645737989
#  0.22137292109383797

# %%
function plotLogistic( r, N )
    x=generate(r,N)
    plt = plot(x
        ,markershape=:square ,markercolor=:maroon
        ,linecolor=:pink ,lw=1
        ,label="r = " *string(r)
        ,xlabel="number of iterations"
        ,ylabel="x-values"
        ,ylim=(0,1)
    )
    return plt
end

plotLogistic(r) = plotLogistics( r, N )
# Out:
# plotLogistic (generic function with 2 methods)

# %%
plotLogistic(3.701, 200)

# %%
function generate( r, N )
    xval = rand();
    x = xval;
    for _ in 2:N
        xval = r * xval * (1 .- xval)
        x = vcat(x, xval)
    end
    return x;
end

generate(r) = generate( r, 200 )

x = generate(3.75)

function plotLogistic( r, N )
    x=generate(r,N)
    plt = plot(x
        ,markershape=:square ,markercolor=:maroon
        ,linecolor=:pink ,lw=1
        ,label="r=" *string(r)
        ,xlabel="number of iterations"
        ,ylabel="x-values"
        ,ylim=(0,1)
    )
    return plt
end

plotLogistic(r) = plotLogistics( r, N )
plotLogistic(3.75, 200)
